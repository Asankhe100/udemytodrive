# %% [markdown]
#    # **FACEBOOK:-  [ KAMRUL HOSSAIN](https://www.facebook.com/Kamrul5258)**

# %% [markdown]
# # <center><a href="https://m.me/kamrul5258"><img src='https://imgur.com/tuWoufI.png' height="70" alt="messenger"/></a><a href="https://www.youtube.com/channel/UC-urDHwTV9zeU8J1u1PqdZQ"><img src='https://imgur.com/tdxDEHH.png' height="70" alt="Youtube "/></a><a href="https://www.facebook.com/groups/TECHLAVA/"><img src='https://imgur.com/rA6YioD.png' height="80" alt="Facebook"/></a><img src="https://hitcounter.pythonanywhere.com/count/tag.svg?url=https%3A%2F%2Fgithub.com%2Fbiplobsd%2FOneClickRun" alt="Hits" align="right"></center>

# %%
#@markdown <h3>⬅ Run This Cell to Install Gitpython 
# !pip install gitpython

# %%
#@markdown <h3>⬅ Run This Cell to  Mount Gdrive
from google.colab import drive
drive.mount('/content/drive')

# %%
#@markdown <h3>⬅ Run This Cell to Clone the Github Repo
import git
import os
git.Git("/content").clone("https://github.com/shel404/udemy-dl.git")
os.chdir("/content/udemy-dl")

# %%
#@markdown <h3>⬅ Run This Cell to Required Package
# !pip install -r requirements.txt

# %%
#@markdown <h3>Paste your access token in the textbox ⬇ and run this cell
Access_Token = "" #@param {type:"string"}
f = open("cookie.txt", "w")
f.write(f'access_token={Access_Token}')
f.close()

# %%
#@markdown <h3>Paste the course link ⬇ and run
Course_Link = "" #@param {type:"string"}

# !python udemy-dl.py $Course_Link -k cookie.txt -o "/content/drive/My Drive"
